# %%
import numpy as np
import pandas as pd

man_to_man,no_sleves=pd.read_csv(r"C:\Users\jaeyeon\Desktop\man_to_man.csv",index_col=0),pd.read_csv(r"C:\Users\jaeyeon\Desktop\no_sleves.csv",index_col=0)

# %%
man_to_man.sort_values(by=['구매욕상승'],ascending=False)
# Out:
#       중분류    브랜드                                                상품명  \
# 1020  맨투맨   모코블링  [오늘출발&무배]스코틀랜드1890 #자수맨투맨 #기모안감 #오버핏맨투맨 #루즈핏맨투...
# 740   맨투맨     라룸                           [오늘출발｜by LAROOM] 그린데일맨투맨
# 1416  맨투맨    메이글                  [🏆1천장돌파💘오늘출발] 런던 자수 맨투맨 - 3 color
# 1680  맨투맨   데일리쥬                      [1만장판매] 테이드 헨리넥 맨투맨 - 6 color
# 216   맨투맨    지니즈  [당일오트,기모네이비,그레이]✨50000장돌파✨자체제작 파라다이스 맨투맨 (4color)
# ...   ...    ...                                                ...
# 1581  맨투맨   데일리쥬     [3천장판매/MADE] 수잔 크롭 오프숄더 맨투맨(기모버전 추가) - 5 color
# 1582  맨투맨   데일리쥬     [3천장판매/MADE] 수잔 크롭 오프숄더 맨투맨(기모버전 추가) - 5 color
# 1583  맨투맨   데일리쥬     [3천장판매/MADE] 수잔 크롭 오프숄더 맨투맨(기모버전 추가) - 5 color
# 1584  맨투맨   데일리쥬     [3천장판매/MADE] 수잔 크롭 오프숄더 맨투맨(기모버전 추가) - 5 color
# 2166  맨투맨  슈가파우더                [13컬러*사이즈선택/슈가MADE] 포시즌 특양면 오버핏 맨투맨
#
#                                                      리뷰          날짜   사이즈_평가  \
# ...

# %%
no_sleves
# Out:
#             중분류    브랜드                                                상품명  \
# 0     민소매_슬리브리스  슬로우앤드  [8천장돌파/여행룩추천!] #SLOWMADE. 해브 스트라이프 슬리브리스 - 4 c...
# 1     민소매_슬리브리스  슬로우앤드  [8천장돌파/여행룩추천!] #SLOWMADE. 해브 스트라이프 슬리브리스 - 4 c...
# 2     민소매_슬리브리스  슬로우앤드  [8천장돌파/여행룩추천!] #SLOWMADE. 해브 스트라이프 슬리브리스 - 4 c...
# 3     민소매_슬리브리스  슬로우앤드  [8천장돌파/여행룩추천!] #SLOWMADE. 해브 스트라이프 슬리브리스 - 4 c...
# 4     민소매_슬리브리스  슬로우앤드  [8천장돌파/여행룩추천!] #SLOWMADE. 해브 스트라이프 슬리브리스 - 4 c...
# ...         ...    ...                                                ...
# 7830  민소매_슬리브리스  비마이뮤즈  [유교걸/1만개돌파!/부유방커버!] 치즈 일자 라인 이너 탑 여름 끈나시 스퀘어넥 ...
# 7831  민소매_슬리브리스  비마이뮤즈  [유교걸/1만개돌파!/부유방커버!] 치즈 일자 라인 이너 탑 여름 끈나시 스퀘어넥 ...
# 7832  민소매_슬리브리스  비마이뮤즈  [유교걸/1만개돌파!/부유방커버!] 치즈 일자 라인 이너 탑 여름 끈나시 스퀘어넥 ...
# 7833  민소매_슬리브리스  비마이뮤즈  [유교걸/1만개돌파!/부유방커버!] 치즈 일자 라인 이너 탑 여름 끈나시 스퀘어넥 ...
# 7834  민소매_슬리브리스  비마이뮤즈  [유교걸/1만개돌파!/부유방커버!] 치즈 일자 라인 이너 탑 여름 끈나시 스퀘어넥 ...
#
#                                                      리뷰          날짜  사이즈_평가  \
# ...
