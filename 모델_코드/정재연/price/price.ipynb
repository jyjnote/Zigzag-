# %%
import numpy as np
import random # 시드 고정을 위해
import os # 시드 고정을 위해
import pandas as pd
import joblib

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

import torch
from torch import Tensor,tensor
from torch.utils.data import DataLoader,Dataset
from torch.nn import Module,Sequential

device= 'cuda' if torch.cuda.is_available() else 'cpu'

def reset_seeds(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

import pymysql
import pandas as pd

conn = pymysql.connect(host='127.0.0.1', user='wodus1530',
                       password='dkvms7255', db='Zigzag')


cursor = conn.cursor()


sql_query = 'SELECT * FROM db'
cursor.execute(sql_query)

result = cursor.fetchall()
column_names = [i[0] for i in cursor.description]


db = pd.DataFrame(result, columns=column_names)

cursor.close()
conn.close()

# %%
price_data_1 = pd.DataFrame(db[db['가격.1'] != 0]['리뷰'], columns=['리뷰']).reset_index(drop=True)
price_data_1['target'] = 1

price_data_2 = pd.DataFrame(db[db['가격.1'] == 0]['리뷰'], columns=['리뷰']).reset_index(drop=True)
price_data_2['target'] = 0

price_data = pd.concat([price_data_1, price_data_2], axis=0).reset_index(drop=True)
price_data.isnull().sum()
# Out:
# 리뷰        0
# target    0
# dtype: int64

# %%
from mecab import MeCab
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer

filter=['NNG','MAG','EC','VA','VA+EF','VV+ETM','NNB+JKB','VCP+EC','VCP','MAG+JX','VCN']

def tokenizer(data):
    tokenizer = MeCab()
    
    list = []
    
    for text in tqdm(data["리뷰"]):
        prah = []  
        lst = tokenizer.pos(text)  
        for word, pos in lst:
            if pos in filter:
                prah.append(word)  
        list.append(' '.join(prah))  
    
    return pd.DataFrame({'tokens':list})

DB_list=tokenizer(price_data)

from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=100)
legacy_tfidf = vectorizer.fit_transform(DB_list["tokens"])

joblib.dump(vectorizer,'price_vectorizer.pkl')

legacy_tfidf=legacy_tfidf.toarray()

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

legacy_tfidf = scaler.fit_transform(legacy_tfidf)

joblib.dump(scaler,'price_scaler.pkl')

from catboost import CatBoostClassifier


catboost_model = CatBoostClassifier(random_state=42, verbose=0)


catboost_model.fit(legacy_tfidf, price_data['target'])


feature_importances = catboost_model.feature_importances_

feature_names = vectorizer.get_feature_names_out()


sorted_indices = np.argsort(feature_importances)[::-1]
sorted_feature_importances = feature_importances[sorted_indices]
sorted_feature_names = feature_names[sorted_indices]
# Out:
# 100%|██████████| 5135/5135 [00:03<00:00, 1520.05it/s]

# %%
top_10_indices = sorted_indices[:10]

legacy_tfidf_filtered = legacy_tfidf[:, top_10_indices]

# %%
joblib.dump(top_10_indices,'price_col.pkl')
# Out:
# ['price_col.pkl']

# %%
import optuna
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score

# Define the objective function for optimization
def objective(trial):
    # Define the search space
    params = {
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
        'depth': trial.suggest_int('depth', 4, 10),
        'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
        'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
    }
    
    # Initialize CatBoostClassifier with suggested parameters
    catboost_model = CatBoostClassifier(**params, random_state=42, verbose=0)
    
    # Split the data into train and validation sets
    X_train, X_val, y_train, y_val = train_test_split(legacy_tfidf_filtered, price_data['target'], test_size=0.2, random_state=42)
    
    # Fit the model
    catboost_model.fit(X_train, y_train, eval_set=(X_val, y_val), early_stopping_rounds=10, verbose=False)
    
    # Get validation predictions
    y_pred = catboost_model.predict(X_val)
    
    # Calculate precision, recall, and F1 score for class '1'
    precision = precision_score(y_val, y_pred, pos_label=1)
    recall = recall_score(y_val, y_pred, pos_label=1)
    f1 = f1_score(y_val, y_pred, pos_label=1)
    
    return f1

# Create an Optuna study object
study = optuna.create_study(direction='maximize')

# Optimize the objective function
study.optimize(objective, n_trials=50)

# Get the best parameters and best score
best_params = study.best_params
best_score = study.best_value

print("Best Parameters:", best_params)
print("Best F1 Score for class '1':", best_score)

# Train CatBoostClassifier with the best parameters
best_catboost_model = CatBoostClassifier(**best_params, random_state=42, verbose=0)
# Out:
# [I 2024-02-19 19:29:08,330] A new study created in memory with name: no-name-21a54882-6f06-4ee9-86e6-2e8f0b294033
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:29:09,375] Trial 0 finished with value: 0.6290322580645161 and parameters: {'iterations': 363, 'learning_rate': 0.0027434267424829043, 'depth': 5, 'l2_leaf_reg': 1.7515900409984198, 'border_count': 80, 'random_strength': 1.0250029719399647, 'bagging_temperature': 4.543639101649079}. Best is trial 0 with value: 0.6290322580645161.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:29:13,956] Trial 1 finished with value: 0.6229508196721312 and parameters: {'iterations': 708, 'learning_rate': 0.0011546266371527975, 'depth': 8, 'l2_leaf_reg': 3.681418109751116, 'border_count': 230, 'random_strength': 2.9297893810647366, 'bagging_temperature': 2.765545644879426}. Best is trial 0 with value: 0.6290322580645161.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:29:14,606] Trial 2 finished with value: 0.6147540983606558 and parameters: {'iterations': 858, 'learning_rate': 0.016683313459402195, 'depth': 5, 'l2_leaf_reg': 1.1746415345703844, 'border_count': 79, 'random_strength': 1.7978020430341088, 'bagging_temperature': 0.42603116180593037}. Best is trial 0 with value: 0.6290322580645161.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:29:14,868] Trial 3 finished with value: 0.6180257510729614 and parameters: {'iterations': 135, 'learning_rate': 0.013067507050769272, 'depth': 4, 'l2_leaf_reg': 9.830472671421917, 'border_count': 197, 'random_strength': 4.574622967182891, 'bagging_temperature': 0.9479105517287804}. Best is trial 0 with value: 0.6290322580645161.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:29:15,126] Trial 4 finished with value: 0.6428571428571429 and parameters: {'iterations': 134, 'learning_rate': 0.004381336807336646, 'depth': 5, 'l2_leaf_reg': 4.3043134551100195, 'border_count': 146, 'random_strength': 0.19161963674238666, 'bagging_temperature': 0.3141979224203399}. Best is trial 4 with value: 0.6428571428571429.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:29:15,535] Trial 5 finished with value: 0.6172839506172839 and parameters: {'iterations': 155, 'learning_rate': 0.025948787018737245, 'depth': 7, 'l2_leaf_reg': 7.561627559984227, 'border_count': 62, 'random_strength': 2.3151766837243866, 'bagging_temperature': 0.7238169083420344}. Best is trial 4 with value: 0.6428571428571429.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:29:19,280] Trial 6 finished with value: 0.6290322580645161 and parameters: {'iterations': 566, 'learning_rate': 0.001192368532316718, 'depth': 8, 'l2_leaf_reg': 1.0023350001909577, 'border_count': 177, 'random_strength': 1.6314085870198602, 'bagging_temperature': 4.134643540635926}. Best is trial 4 with value: 0.6428571428571429.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:29:19,491] Trial 7 finished with value: 0.6234817813765182 and parameters: {'iterations': 344, 'learning_rate': 0.07205558726396882, 'depth': 4, 'l2_leaf_reg': 1.8058025681206324, 'border_count': 40, 'random_strength': 1.8583937899835985, 'bagging_temperature': 3.384763258023308}. Best is trial 4 with value: 0.6428571428571429.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19

# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:30:40,715] Trial 42 finished with value: 0.6377952755905512 and parameters: {'iterations': 246, 'learning_rate': 0.0012423474265881443, 'depth': 6, 'l2_leaf_reg': 8.170468574530574, 'border_count': 187, 'random_strength': 0.11116191882383854, 'bagging_temperature': 6.263975723619385}. Best is trial 41 with value: 0.6666666666666666.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:30:41,195] Trial 43 finished with value: 0.6666666666666666 and parameters: {'iterations': 158, 'learning_rate': 0.001016741311950798, 'depth': 6, 'l2_leaf_reg': 8.775003950989115, 'border_count': 216, 'random_strength': 0.12505805962332, 'bagging_temperature': 2.3388372686573837}. Best is trial 41 with value: 0.6666666666666666.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:30:41,685] Trial 44 finished with value: 0.6616541353383458 and parameters: {'iterations': 148, 'learning_rate': 0.0011240164477960223, 'depth': 6, 'l2_leaf_reg': 8.746982566914632, 'border_count': 221, 'random_strength': 0.10057876026481391, 'bagging_temperature': 2.527908356174552}. Best is trial 41 with value: 0.6666666666666666.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:30:42,180] Trial 45 finished with value: 0.6641509433962264 and parameters: {'iterations': 162, 'learning_rate': 0.001101558475860642, 'depth': 6, 'l2_leaf_reg': 8.982016915131775, 'border_count': 231, 'random_strength': 0.10003391383008894, 'bagging_temperature': 2.4734718025167477}. Best is trial 41 with value: 0.6666666666666666.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:30:42,759] Trial 46 finished with value: 0.6666666666666666 and parameters: {'iterations': 150, 'learning_rate': 0.0010286943289365563, 'depth': 6, 'l2_leaf_reg': 8.737921670957526, 'border_count': 223, 'random_strength': 0.12351192344258871, 'bagging_temperature': 2.4920700726646388}. Best is trial 41 with value: 0.6666666666666666.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:30:43,178] Trial 47 finished with value: 0.6641221374045801 and parameters: {'iterations': 163, 'learning_rate': 0.0010278226698669296, 'depth': 6, 'l2_leaf_reg': 8.938424545284901, 'border_count': 255, 'random_strength': 0.1629705083266872, 'bagging_temperature': 4.640786966495037}. Best is trial 41 with value: 0.6666666666666666.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:30:43,513] Trial 48 finished with value: 0.6641509433962264 and parameters: {'iterations': 101, 'learning_rate': 0.0017915739719270702, 'depth': 6, 'l2_leaf_reg': 9.327384505509201, 'border_count': 255, 'random_strength': 0.15544993759397857, 'bagging_temperature': 4.522249506014741}. Best is trial 41 with value: 0.6666666666666666.
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:11: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 0.1),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:13: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'random_strength': trial.suggest_loguniform('random_strength', 0.1, 10),
# C:\Users\jaeyeon\AppData\Local\Temp\ipykernel_19000\2022388496.py:16: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'bagging_temperature': trial.suggest_loguniform('bagging_temperature', 0.1, 10)
# [I 2024-02-19 19:30:43,797] Trial 49 finished with value: 0.6615384615384615 and parameters: {'iterations': 100, 'learning_rate': 0.00171351635530709, 'depth': 5, 'l2_leaf_reg': 7.155480206152415, 'border_count': 234, 'random_strength': 0.12937354512168264, 'bagging_temperature': 3.3264329000896105}. Best is trial 41 with value: 0.6666666666666666.
# Best Parameters: {'iterations': 155, 'learning_rate': 0.0011072856224018084, 'depth': 6, 'l2_leaf_reg': 7.625139097584858, 'border_count': 188, 'random_strength': 0.12190208000106528, 'bagging_temperature': 5.420910109735578}
# Best F1 Score for class '1': 0.6666666666666666

# %%
best_catboost_model.fit(legacy_tfidf_filtered, price_data['target'])
joblib.dump(best_catboost_model, 'price_catboost_model.pkl')
# Out:
# ['price_catboost_model.pkl']
